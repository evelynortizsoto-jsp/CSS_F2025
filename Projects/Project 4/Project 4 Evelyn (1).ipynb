# %% [markdown]
# # [Computational Social Science] Project 4: Unsupervised Learning
#
# **Evelyn Ortiz Soto**
#
# *Semester:* Fall 2025

# %% [markdown]
# ## Data Description and Preprocessing
#
# For this project, you will explore data from the [National Health and Nutrition Examination Survey](https://www.kaggle.com/cdc/national-health-and-nutrition-examination-survey?select=questionnaire.csv). NHANES is a unique study that combines survey methodology with in-person medical examinations to create a dataset with demographic information, health indicators, and health outcomes.

# %% [markdown]
# We start by importing the data and doing some preliminary preprocessing for you. We import some libraries that will be helpful as well. 'SEQN' is the ID number for each respondent, and 'HSD010' will be our target outcome. [HSD010](https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/HSQ_H.htm#HSD010) asks for the respondent's self reported health condition, which can range from "excellent" to "poor."

# %%
import sys
# !{sys.executable} -m pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /srv/conda/lib/python3.11/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /srv/conda/lib/python3.11/site-packages (from tensorflow) (75.6.0)
# Requirement already satisfied: six>=1.12.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Using cached grpcio-1.76.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.7 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.13.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in /srv/conda/lib/python3.11/site-packages (from tensorflow) (2.2.6)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Using cached h5py-3.15.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in /srv/conda/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (11.1.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: rich in /srv/conda/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Using cached optree-0.18.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in /srv/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /srv/conda/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /srv/conda/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /srv/conda/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.6 MB)
# Using cached grpcio-1.76.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.6 MB)
# Using cached ml_dtypes-0.5.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.15.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.7 MB)
# Downloading keras-3.13.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.6 MB/s eta 0:00:00
# Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Using cached werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.18.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (400 kB)
# Installing collected packages: namex, libclang, flatbuffers, werkzeug, termcolor, tensorboard-data-server, optree, opt_einsum, ml_dtypes, markdown, h5py, grpcio, google_pasta, gast, absl-py, tensorboard, keras, tensorflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [tensorflow]8 [tensorflow]]]
# Successfully installed absl-py-2.3.1 flatbuffers-25.9.23 gast-0.7.0 google_pasta-0.2.0 grpcio-1.76.0 h5py-3.15.1 keras-3.13.0 libclang-18.1.1 markdown-3.10 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.18.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 werkzeug-3.1.4

# %%
# Import libraries
# Import libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
sns.set_style("darkgrid")
from sklearn.model_selection import train_test_split
# Out:
# 2025-12-17 17:58:09.320123: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-17 17:58:09.320544: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 17:58:09.383079: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# /srv/conda/lib/python3.11/site-packages/google/protobuf/runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# 2025-12-17 17:58:11.296100: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-17 17:58:11.297492: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /srv/conda/lib/python3.11/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
# Load nhanes data
nhanes = pd.read_csv('nhanes.csv')
# Get the ID numbers for each observation (seqn)
seqn = nhanes['SEQN']
# Get the target, "self-reported health condition," HSD010
hsd010 = nhanes['HSD010']
# Drop SEQN from the dataframe and then apply the standard scaler
nhanes = nhanes.drop(['SEQN', 'HSD010'], axis = 1)
nhanes_scaled = pd.DataFrame(StandardScaler().fit_transform(nhanes),
                             columns = nhanes.columns)
# Add the ID and target back in
nhanes_scaled['SEQN'] = seqn
nhanes_scaled['HSD010'] = hsd010
nhanes_scaled = nhanes_scaled.set_index('SEQN')
nhanes_scaled.head()
# Out:
#        DR1DRSTZ  DR1EXMER  DRABF    DRDINT   DR1DBIH    DR1DAY   DR1LANG  \
# SEQN
# 73568       0.0  2.034312    0.0  0.324834 -0.393906  1.085853 -0.194202
# 73576       0.0  0.261930    0.0 -3.078499  0.568251  0.634362 -0.194202
# 73579       0.0  0.728346    0.0  0.324834  1.530407 -1.623092 -0.194202
# 73581       0.0 -0.857470    0.0  0.324834  0.480782  1.085853 -0.194202
# 73584       0.0  0.495138    0.0  0.324834  0.305844 -1.623092 -0.194202
#
#        DR1MNRSP  DR1HELPD   DBQ095Z  ...    OHQ770    OHQ845   PAAQUEX  \
# SEQN                                 ...
# 73568 -0.057306  0.128246 -0.189513  ...  0.383802 -0.646584 -0.484200
# 73576 -0.057306  0.128246  0.080373  ...  0.383802 -1.539259 -0.484200
# 73579 -0.057306  0.128246 -0.189513  ...  0.383802 -1.539259  2.065262
# 73581 -0.057306  0.128246  0.080373  ...  0.383802 -0.646584 -0.484200
# 73584 -0.057306  0.128246  0.080373  ... -2.605509  0.246091  2.065262
#
#          SMQ860  SMQ870    SMQ872    SMQ874    SMQ878  SMAQUEX.x  HSD010
# SEQN
# 73568  1.125008     0.0 -2.081666  1.087115  1.463404   0.612440       1
# 73576  1.125008     0.0 -2.081666  1.087115 -0.683338  -1.632812       1
# 73579 -0.888883     0.0  0.480384 -0.919866 -0.683338  -1.632812       2
# 73581  1.125008     0.0  0.480384 -0.919866 -0.683338   0.612440       2
# 73584  1.125008     0.0  0.480384 -0.919866  1.463404  -1.632812       3
#
# [5 rows x 242 columns]

# %% [markdown]
# ## Plots

# %% [markdown]
# Let's take a look at the data. Below we visualize boxplots of family income to federal poverty line ratio ('INDFMPIR') and self-reported health condition. Notice how there are some clear patterns (the lower the ratio, the lower reported health condition), but it's not a perfect separation. We have 240+ features in our dataset, and we likely have several features in our dataset that highly correlate with our family income-poverty line ratio measure - PCA will help us simplify these.

# %%
# Create a binary version of hsd010 where 1-3 are "good" and 4-5 are "poor"
nhanes_scaled['HSD010_binary'] = hsd010_binary = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['good', 'good', 'good', 'poor', 'poor']) 
# Recode the original hsd010 with the string labels
nhanes_scaled['HSD010'] = nhanes_scaled['HSD010'].replace(
    [1, 2, 3, 4, 5], ['excellent', 'very good', 'good', 'fair', 'poor'])
# Boxplot of hsd010
ax = sns.boxplot(x = 'HSD010', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Self-Reported Health Status")
plt.show()

# %%
# Boxplot of hsd010_binary
ax = sns.boxplot(x = 'HSD010_binary', y = 'INDFMPIR', data = nhanes_scaled)
ax.set(xlabel = "Self Reported Health Condition",
      ylabel = "Family Income to Poverty Line Ratio")
ax.set_title("Boxplot of Family Income to Poverty Line Ratio by Binary Self-Reported Health Status")
plt.show()

# %% [markdown]
# Family income also is not necessarily well correlated with measured health outcomes. See below where we look at the relationship between Body Mass Index (BMI) and the family income-poverty line ratio, and shade points by self-reported health condition. It's hard to find a clear pattern - this is where clustering may come in handy.

# %%
ax = sns.scatterplot(x = "INDFMPIR", y = "BMXBMI", hue = "HSD010", palette = "tab10", data = nhanes_scaled)
ax.set(xlabel = "Income to Poverty Line Ratio",
      ylabel = "Body Mass Index")
ax.set_title("BMI v. Income-Poverty Ratio")
plt.show()

# %% [markdown]
# Before we move to working on unsupervised methods, we'll drop our target variables again:

# %%
nhanes_scaled = nhanes_scaled.drop(['HSD010', 'HSD010_binary'], axis = 1)

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# Conduct a Principal Component Analysis (PCA) of the nhanes data. The data has already been prepared for you, so you can work directly on nhanes_scaled. Be sure to do the following:
#
# - Choose the number of components and provide 1-2 sentences about your choice of the number of components.
# - Plot a barplot of the variation explained by each component. *Hint*: look at the attributes associated with your model.
# - Choose how many components you will use to fit a supervised learning model and provide 1-2 sentences to explain that choice.
# - Plot a 2D scatterplot of the first two components and provide 1-2 sentences analyzing the plot.

# %% [markdown]
# ### Train PCA and Discuss Number of Components

# %%
from sklearn.decomposition import PCA
import numpy as np

# Fit PCA with all components first to see explained variance
pca_full = PCA()
pca_full.fit(nhanes_scaled)

# Calculate cumulative explained variance
cumulative_variance = np.cumsum(pca_full.explained_variance_ratio_)

# Find number of components for 80%, 90%, 95% variance
n_80 = np.argmax(cumulative_variance >= 0.80) + 1
n_90 = np.argmax(cumulative_variance >= 0.90) + 1
n_95 = np.argmax(cumulative_variance >= 0.95) + 1

print(f"Components for 80% variance: {n_80}")
print(f"Components for 90% variance: {n_90}")
print(f"Components for 95% variance: {n_95}")
print(f"Total cumulative variance with {n_90} components: {cumulative_variance[n_90-1]:.3f}")

# Discussion: I chose [pick one, e.g., n_90] components because they capture [XX]% 
# of the variance, which balances dimensionality reduction with information retention.
# Out:
# Components for 80% variance: 86
# Components for 90% variance: 120
# Components for 95% variance: 145
# Total cumulative variance with 120 components: 0.902

# %% [markdown]
# **Discussion:** I chose 120 components (90% variance threshold) because this provides a good balance between dimensionality reduction (from 241 to 120 features) and information retention. This captures sufficient variance while reducing model complexity and helping prevent overfitting.

# %% [markdown]
# ### Barplot of Components

# %%
import matplotlib.pyplot as plt

# Plot explained variance by component
plt.figure(figsize=(12, 5))
plt.bar(range(1, min(51, len(pca_full.explained_variance_ratio_) + 1)), 
        pca_full.explained_variance_ratio_[:50])
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Variance Explained by Each Principal Component')
plt.show()

# %% [markdown]
# ### How many components will you use to fit a supervised learning model?

# %%
# Choose based on your analysis above (e.g., 90% threshold)
n_components_final = n_90  # or n_80, n_95 depending on your choice

# Refit PCA with chosen number of components
pca = PCA(n_components=n_components_final)
X_pca = pca.fit_transform(nhanes_scaled)

print(f"Selected {n_components_final} components for supervised learning.")
print(f"These components explain {pca.explained_variance_ratio_.sum():.3f} of total variance.")

# Discussion: I selected [n] components because [they capture sufficient variance 
# while significantly reducing dimensionality from ~250 features, helping prevent overfitting]
# Out:
# Selected 120 components for supervised learning.
# These components explain 0.901 of total variance.

# %% [markdown]
# ### 2D Scatterplot of the first two components

# %%
# Load the original data to get the target variable
import pandas as pd
nhanes_original = pd.read_csv('nhanes.csv')  # Adjust path if needed

# Extract target variable
y = nhanes_original['HSD010']  # Try uppercase first
# If that doesn't work, try: y = nhanes_original['hsd010']

# Make sure y aligns with X_pca (same number of rows)
print(f"X_pca shape: {X_pca.shape}")
print(f"y shape: {y.shape}")

# Create scatterplot of first two components
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                     c=y,  
                     cmap='viridis', alpha=0.6)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('2D PCA Scatterplot Colored by Health Condition')
plt.colorbar(scatter, label='Health Condition (HSD010)')
plt.show()

# Analysis: The plot shows the distribution of observations across the first two 
# principal components. There is significant overlap between health conditions, 
# suggesting that the relationship is complex and may require more components 
# to fully capture the variation related to self-reported health.
# Out:
# X_pca shape: (2064, 120)
# y shape: (2064,)

# %% [markdown]
# **Analysis:** The 2D PCA scatterplot shows considerable overlap between different health condition categories (represented by different colors). This suggests that the first two principal components alone don't clearly separate health outcomes, indicating that multiple dimensions are needed to capture the complexity of factors affecting self-reported health status.

# %% [markdown]
# ## Clustering

# %% [markdown]
# - Choose a clustering algorithm and explain it in 1-2 sentences.
# - Cluster the nhanes data. Detail any choice you need to make with regards to number of clusters, and how you arrived at that choice. For instance, you might use the [elbow method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)) if you choose k-means.
# - Plot your clusters on top of BMI v. Income Poverty Ratio Plot. Describe what you see in 1-2 sentences.
# - Retrain the clustering algorithm, but this time use your PCA results instead of the original dataframe. Plot the clusters on top of the 2D PCA scatterplot from the previous step. Describe your results in 1-2 sentences.

# %% [markdown]
# ### Choose a Clustering Algorithm

# %%
from sklearn.cluster import KMeans

# I will use K-Means clustering algorithm. K-Means partitions data into k clusters
# by minimizing within-cluster variance, assigning each point to the nearest centroid.

# %% [markdown]
# ### Cluster nhanes

# %%
# Use elbow method to determine optimal number of clusters
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculate inertia (within-cluster sum of squares) for different k values
inertias = []
K_range = range(2, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(nhanes_scaled)
    inertias.append(kmeans.inertia_)

# Plot elbow curve
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertias, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (Within-Cluster Sum of Squares)')
plt.title('Elbow Method for Optimal k')
plt.grid(True)
plt.show()

# Choose k based on the elbow (where curve starts to flatten)
optimal_k = 4  # Adjust based on your elbow plot - look for the "elbow" point

# Fit final model with chosen k
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
clusters = kmeans.fit_predict(nhanes_scaled)

print(f"Chose {optimal_k} clusters based on the elbow method, where the rate of ")
print(f"decrease in inertia begins to level off, indicating diminishing returns.")
# Out:
# Chose 4 clusters based on the elbow method, where the rate of
# decrease in inertia begins to level off, indicating diminishing returns.

# %% [markdown]
# ### Plot your clusters on top of the BMI v. Income Poverty Ratio Plot

# %%
# Get BMI and Income-Poverty Ratio columns
# First, let's find these columns in the original data
nhanes_original = pd.read_csv('nhanes.csv')

# Look for BMI and income-poverty columns
bmi_col = [col for col in nhanes_original.columns if 'BMI' in col.upper()]
income_col = [col for col in nhanes_original.columns if 'POVERTY' in col.upper() or 'INCOME' in col.upper()]

print("BMI columns:", bmi_col)
print("Income/Poverty columns:", income_col)

# Assuming the columns are named something like 'BMXBMI' and 'INDFMPIR'
# Adjust these names based on what you find above
bmi = nhanes_original['BMXBMI']  # Adjust column name if needed
income_poverty = nhanes_original['INDFMPIR']  # Adjust column name if needed

# Plot
plt.figure(figsize=(10, 8))
scatter = plt.scatter(income_poverty, bmi, c=clusters, cmap='viridis', alpha=0.6)
plt.xlabel('Income to Poverty Ratio')
plt.ylabel('BMI')
plt.title('Clusters on BMI v. Income-Poverty Ratio')
plt.colorbar(scatter, label='Cluster')
plt.show()

# Analysis: The clusters show [describe what you see - e.g., "distinct groupings that
# capture different health and socioeconomic profiles, with some clusters showing
# higher BMI regardless of income level"]
# Out:
# BMI columns: ['BMXBMI']
# Income/Poverty columns: []

# %% [markdown]
# **Analysis:** The clusters reveal distinct groupings that don't align perfectly with either BMI or income individually. Some clusters show higher BMI across various income levels, suggesting the algorithm identified multidimensional health-socioeconomic profiles beyond what these two variables alone capture.

# %% [markdown]
# ### Retrain the clustering algorithm on PCA components and plot clusters on your 2D scatter

# %%
# Cluster using PCA components instead of original features
kmeans_pca = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
clusters_pca = kmeans_pca.fit_predict(X_pca)

# Plot clusters on 2D PCA scatterplot
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], 
                     c=clusters_pca, 
                     cmap='viridis', alpha=0.6)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title('Clusters on 2D PCA Scatterplot')
plt.colorbar(scatter, label='Cluster')
plt.show()

# Analysis: Clustering on PCA components shows [describe - e.g., "clearer separation
# between clusters, as PCA has removed noise and captured the main sources of
# variation in the data"]

# %% [markdown]
# **Analysis:** Clustering on PCA components shows more distinct cluster boundaries compared to the original feature space. PCA removed noise and captured the main sources of variation, making it easier for k-means to identify meaningful groups. The clusters appear more evenly distributed across the principal component space.

# %% [markdown]
# ## Neural Network

# %% [markdown]
# Now we are ready to predict! Do the following:
#
# - Choose either HSD010 or HSD010\_binary as your target outcome.
# - Train a neural network using the original features. Much of the code to train a basic neural net has been set up for you, but you will need to fill in a couple of missing pieces.
# - Train a neural network using only your PCA components as features.
# - Train a neural network using your PCA components and the predicted class membership from your clustering algorithm as features.
# - Compare and contrast how well each algorithm did. Which featurization technique would you pick and why?

# %% [markdown]
# Below we provide a template for training a neural network. Use this template for training on the original features, on the PCA components, and the PCA components + the predicted classes from your clusters.

# %% [markdown]
# ### Neural Network on Original Features

# %%
# partition data
# Choose target - either hsd010 or hsd010_binary
from sklearn.model_selection import train_test_split

y = nhanes_original['HSD010']  # or 'hsd010' depending on case
X = nhanes_scaled  # drop out any columns that aren't features

# Convert to numeric if needed (HSD010 is categorical 1-5)
# If using HSD010, you may want to subtract 1 to make it 0-4 for neural networks
y = y - 1  # Now ranges from 0-4

# Split data - only ONE random_state parameter
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=10)

print(f"Training set: {X_train.shape}")
print(f"Test set: {X_test.shape}")
# Out:
# Training set: (1548, 241)
# Test set: (516, 241)

# %%
# load libraries
import keras
from keras.utils import to_categorical

# Get number of classes
num_classes = len(y_test.unique())  # Should be 5 for HSD010, 2 for binary

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
num_classes = y_test.shape[1]

print(f"Number of classes: {num_classes}")
print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Number of classes: 5
# Training set size: 1548
# Test set size: 516

# %%
from keras.models import Sequential
from keras.layers import Dense

# create neural network model
model = Sequential()

# Input layer + first hidden layer
model.add(Dense(128, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

# Second hidden layer
model.add(Dense(64, kernel_initializer='normal', activation='relu'))

## Add any additional layers you wish here
# model.add(Dense(32, kernel_initializer='normal', activation='relu'))

# Output layer - use softmax for multi-class classification
model.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), 
                   epochs=50, batch_size=32, verbose=1)

# Evaluate
score = model.evaluate(X_test, y_test, verbose=0)
print(f'\nTest loss: {score[0]:.4f}')
print(f'Test accuracy: {score[1]:.4f}')
# Out:
# Epoch 1/50
# /srv/conda/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-12-17 17:58:27.243737: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4270 - loss: 1.3745 - val_accuracy: 0.4593 - val_loss: 1.2523
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5052 - loss: 1.1647 - val_accuracy: 0.4729 - val_loss: 1.1863
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5575 - loss: 1.0250 - val_accuracy: 0.4864 - val_loss: 1.1525
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6176 - loss: 0.8925 - val_accuracy: 0.4884 - val_loss: 1.1859
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6893 - loss: 0.7711 - val_accuracy: 0.4748 - val_loss: 1.1940
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7461 - loss: 0.6534 - val_accuracy: 0.4864 - val_loss: 1.3081
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8075 - loss: 0.5348 - val_accuracy: 0.4651 - val_loss: 1.4144
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8540 - loss: 0.4235 - val_accuracy: 0.4399 - val_loss: 1.5066
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8870 - loss: 0.3307 - val_accuracy: 0.4632 - val_loss: 1.6517
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9496 - loss: 0.2341 - val_accuracy: 0.4554 - val_loss: 1.8769
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.1749 - val_accuracy: 0.4496 - val_loss: 2.0142
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9826 - loss: 0.1242 - val_accuracy: 0.4496 - val_loss: 2.1780
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9955 - loss: 0.0743 - val_accuracy: 0.4593 - val_loss: 2.2898
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0480 - val_accuracy: 0.4612 - val_loss: 2.4311
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.4477 - val_loss: 2.5586
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 0.4419 - val_loss: 2.6548
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 0.4516 - val_loss: 2.7676
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.4457 - val_loss: 2.8342
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.4457 - val_loss: 2.9105
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.4457 - val_loss: 2.9748
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.4380 - val_loss: 3.0478
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.4477 - val_loss: 3.1063
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.4438 - val_loss: 3.1560
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.4399 - val_loss: 3.2040
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.4380 - val_loss: 3.2598
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.4438 - val_loss: 3.3131
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.4399 - val_loss: 3.3535
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.4399 - val_loss: 3.3954
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4399 - val_loss: 3.4349
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.4380 - val_loss: 3.4667
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.4360 - val_loss: 3.5086
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.4341 - val_loss: 3.5397
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4360 - val_loss: 3.5718
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.4341 - val_loss: 3.6100
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4360 - val_loss: 3.6423
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4380 - val_loss: 3.6630
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4322 - val_loss: 3.7028
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4341 - val_loss: 3.7265
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4322 - val_loss: 3.7573
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4341 - val_loss: 3.7855
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4360 - val_loss: 3.8056
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4341 - val_loss: 3.8379
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4360 - val_loss: 3.8605
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.3972e-04 - val_accuracy: 0.4322 - val_loss: 3.8902
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.8578e-04 - val_accuracy: 0.4360 - val_loss: 3.9114
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.3581e-04 - val_accuracy: 0.4341 - val_loss: 3.9360
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.8729e-04 - val_accuracy: 0.4341 - val_loss: 3.9574
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.4669e-04 - val_accuracy: 0.4302 - val_loss: 3.9832
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.0376e-04 - val_accuracy: 0.4322 - val_loss: 4.0081
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.6729e-04 - val_accuracy: 0.4322 - val_loss: 4.0293
#
# Test loss: 4.0293
# Test accuracy: 0.4322

# %% [markdown]
# ### Neural Network on Principal Components

# %%
# Train neural network using PCA components
# First, split PCA data
X_pca_train, X_pca_test, y_pca_train, y_pca_test = train_test_split(
    X_pca, y, test_size=.25, random_state=10)

# Convert y to categorical
y_pca_train = keras.utils.to_categorical(y_pca_train, num_classes)
y_pca_test = keras.utils.to_categorical(y_pca_test, num_classes)

# Create model
model_pca = Sequential()
model_pca.add(Dense(128, input_dim=X_pca_train.shape[1], kernel_initializer='normal', activation='relu'))
model_pca.add(Dense(64, kernel_initializer='normal', activation='relu'))
model_pca.add(Dense(num_classes, kernel_initializer='normal', activation='softmax'))

# Compile and fit
model_pca.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history_pca = model_pca.fit(X_pca_train, y_pca_train, validation_data=(X_pca_test, y_pca_test),
                            epochs=50, batch_size=32, verbose=1)

# Evaluate
score_pca = model_pca.evaluate(X_pca_test, y_pca_test, verbose=0)
print(f'\nPCA Model - Test loss: {score_pca[0]:.4f}')
print(f'PCA Model - Test accuracy: {score_pca[1]:.4f}')
# Out:
# Epoch 1/50
# /srv/conda/lib/python3.11/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3876 - loss: 1.3972 - val_accuracy: 0.4612 - val_loss: 1.2731
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5013 - loss: 1.1800 - val_accuracy: 0.4748 - val_loss: 1.1694
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5575 - loss: 1.0342 - val_accuracy: 0.4942 - val_loss: 1.1390
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5950 - loss: 0.9266 - val_accuracy: 0.5000 - val_loss: 1.1573
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6441 - loss: 0.8277 - val_accuracy: 0.5000 - val_loss: 1.1780
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7041 - loss: 0.7316 - val_accuracy: 0.4903 - val_loss: 1.2579
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7584 - loss: 0.6320 - val_accuracy: 0.4729 - val_loss: 1.3022
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8068 - loss: 0.5293 - val_accuracy: 0.4767 - val_loss: 1.3852
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8611 - loss: 0.4270 - val_accuracy: 0.4864 - val_loss: 1.5149
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8986 - loss: 0.3329 - val_accuracy: 0.4787 - val_loss: 1.6389
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9393 - loss: 0.2553 - val_accuracy: 0.4729 - val_loss: 1.7635
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9587 - loss: 0.1949 - val_accuracy: 0.4671 - val_loss: 1.8910
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.1349 - val_accuracy: 0.4671 - val_loss: 2.0592
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0881 - val_accuracy: 0.4690 - val_loss: 2.2326
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9981 - loss: 0.0620 - val_accuracy: 0.4729 - val_loss: 2.3664
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0439 - val_accuracy: 0.4729 - val_loss: 2.4631
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.4593 - val_loss: 2.6001
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.4593 - val_loss: 2.6972
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.4651 - val_loss: 2.7853
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.4535 - val_loss: 2.8705
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0128 - val_accuracy: 0.4477 - val_loss: 2.9286
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.4554 - val_loss: 3.0122
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.4535 - val_loss: 3.0790
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.4477 - val_loss: 3.1287
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.4516 - val_loss: 3.1763
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.4574 - val_loss: 3.2452
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.4457 - val_loss: 3.2951
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.4477 - val_loss: 3.3372
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.4477 - val_loss: 3.3830
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.4477 - val_loss: 3.4264
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.4438 - val_loss: 3.4700
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.4477 - val_loss: 3.5074
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.4380 - val_loss: 3.5436
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.4380 - val_loss: 3.5800
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.4438 - val_loss: 3.6109
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4399 - val_loss: 3.6477
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.4419 - val_loss: 3.6802
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4438 - val_loss: 3.7163
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.4457 - val_loss: 3.7463
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4438 - val_loss: 3.7761
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4438 - val_loss: 3.8021
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4438 - val_loss: 3.8353
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4477 - val_loss: 3.8610
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4419 - val_loss: 3.8831
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4457 - val_loss: 3.9147
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4457 - val_loss: 3.9383
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4477 - val_loss: 3.9656
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4457 - val_loss: 3.9864
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.5544e-04 - val_accuracy: 0.4477 - val_loss: 4.0168
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.0624e-04 - val_accuracy: 0.4477 - val_loss: 4.0383
#
# PCA Model - Test loss: 4.0383
# PCA Model - Test accuracy: 0.4477

# %% [markdown]
# ### Neural Network on Principal Components + Cluster Membership

# %%
# Neural Network on Principal Components + Cluster Membership
# Create combined feature set: PCA components + cluster membership
# Use clusters_pca from section 1.5.1 (clustering on PCA components)
import numpy as np  # Make sure numpy is imported
X_pca_clusters = np.column_stack([X_pca, clusters_pca.reshape(-1, 1)])

print(f"Combined features shape: {X_pca_clusters.shape}")
print(f"PCA components: {X_pca.shape[1]}, Cluster feature: 1")

# Split the data
X_pca_clust_train, X_pca_clust_test, y_pca_clust_train, y_pca_clust_test = train_test_split(
    X_pca_clusters, y, test_size=0.25, random_state=10)

# Convert y to categorical
y_pca_clust_train = keras.utils.to_categorical(y_pca_clust_train, num_classes)
y_pca_clust_test = keras.utils.to_categorical(y_pca_clust_test, num_classes)

# Create model
model_pca_clusters = Sequential()
model_pca_clusters.add(Dense(128, input_dim=X_pca_clust_train.shape[1], 
                              kernel_initializer='normal', activation='relu'))
model_pca_clusters.add(Dense(64, kernel_initializer='normal', activation='relu'))
model_pca_clusters.add(Dense(num_classes, kernel_initializer='normal', 
                              activation='softmax'))

# Compile and fit
model_pca_clusters.compile(loss='categorical_crossentropy', optimizer='adam', 
                           metrics=['accuracy'])
history_pca_clusters = model_pca_clusters.fit(X_pca_clust_train, y_pca_clust_train,
                                               validation_data=(X_pca_clust_test, y_pca_clust_test),
                                               epochs=50, batch_size=32, verbose=1)

# Evaluate
score_pca_clusters = model_pca_clusters.evaluate(X_pca_clust_test, y_pca_clust_test, verbose=0)
print(f'\nPCA + Clusters Model - Test loss: {score_pca_clusters[0]:.4f}')
print(f'PCA + Clusters Model - Test accuracy: {score_pca_clusters[1]:.4f}')
# Out:
# Combined features shape: (2064, 121)
# PCA components: 120, Cluster feature: 1
# Epoch 1/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.4083 - loss: 1.4067 - val_accuracy: 0.4516 - val_loss: 1.2803
# Epoch 2/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5045 - loss: 1.1988 - val_accuracy: 0.4748 - val_loss: 1.1895
# Epoch 3/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5504 - loss: 1.0532 - val_accuracy: 0.5136 - val_loss: 1.1564
# Epoch 4/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5814 - loss: 0.9483 - val_accuracy: 0.4942 - val_loss: 1.1705
# Epoch 5/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6402 - loss: 0.8459 - val_accuracy: 0.4903 - val_loss: 1.1935
# Epoch 6/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6893 - loss: 0.7488 - val_accuracy: 0.4826 - val_loss: 1.2447
# Epoch 7/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7435 - loss: 0.6526 - val_accuracy: 0.4612 - val_loss: 1.3169
# Epoch 8/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7972 - loss: 0.5551 - val_accuracy: 0.4942 - val_loss: 1.4006
# Epoch 9/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8534 - loss: 0.4481 - val_accuracy: 0.4787 - val_loss: 1.5121
# Epoch 10/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8857 - loss: 0.3589 - val_accuracy: 0.4496 - val_loss: 1.6614
# Epoch 11/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9244 - loss: 0.2731 - val_accuracy: 0.4593 - val_loss: 1.8318
# Epoch 12/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9574 - loss: 0.2066 - val_accuracy: 0.4438 - val_loss: 1.9560
# Epoch 13/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9735 - loss: 0.1477 - val_accuracy: 0.4651 - val_loss: 2.1495
# Epoch 14/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.1073 - val_accuracy: 0.4535 - val_loss: 2.3176
# Epoch 15/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0716 - val_accuracy: 0.4360 - val_loss: 2.4377
# Epoch 16/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0525 - val_accuracy: 0.4322 - val_loss: 2.5862
# Epoch 17/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0364 - val_accuracy: 0.4419 - val_loss: 2.7044
# Epoch 18/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0270 - val_accuracy: 0.4438 - val_loss: 2.8141
# Epoch 19/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.4419 - val_loss: 2.9105
# Epoch 20/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0164 - val_accuracy: 0.4283 - val_loss: 2.9955
# Epoch 21/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.4380 - val_loss: 3.0808
# Epoch 22/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.4302 - val_loss: 3.1572
# Epoch 23/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.4302 - val_loss: 3.2204
# Epoch 24/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.4264 - val_loss: 3.2869
# Epoch 25/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.4302 - val_loss: 3.3516
# Epoch 26/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.4283 - val_loss: 3.4184
# Epoch 27/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.4341 - val_loss: 3.4745
# Epoch 28/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.4322 - val_loss: 3.5142
# Epoch 29/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.4302 - val_loss: 3.5600
# Epoch 30/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.4302 - val_loss: 3.6230
# Epoch 31/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.4302 - val_loss: 3.6644
# Epoch 32/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.4283 - val_loss: 3.7082
# Epoch 33/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.4302 - val_loss: 3.7568
# Epoch 34/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.4302 - val_loss: 3.8001
# Epoch 35/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.4302 - val_loss: 3.8423
# Epoch 36/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.4283 - val_loss: 3.8795
# Epoch 37/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.4322 - val_loss: 3.9215
# Epoch 38/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.4264 - val_loss: 3.9591
# Epoch 39/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.4264 - val_loss: 3.9951
# Epoch 40/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.4264 - val_loss: 4.0329
# Epoch 41/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.4264 - val_loss: 4.0643
# Epoch 42/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.4283 - val_loss: 4.0991
# Epoch 43/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4283 - val_loss: 4.1353
# Epoch 44/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.4302 - val_loss: 4.1660
# Epoch 45/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.4283 - val_loss: 4.1989
# Epoch 46/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.4302 - val_loss: 4.2279
# Epoch 47/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.4283 - val_loss: 4.2634
# Epoch 48/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.6512e-04 - val_accuracy: 0.4322 - val_loss: 4.2918
# Epoch 49/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.0168e-04 - val_accuracy: 0.4302 - val_loss: 4.3236
# Epoch 50/50
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.4935e-04 - val_accuracy: 0.4322 - val_loss: 4.3525
#
# PCA + Clusters Model - Test loss: 4.3525
# PCA + Clusters Model - Test accuracy: 0.4322

# %%
# Compare and contrast results
print("=" * 60)
print("MODEL COMPARISON")
print("=" * 60)
print(f"Original Features - Accuracy: {score[1]:.4f}")
print(f"PCA Components    - Accuracy: {score_pca[1]:.4f}")
print(f"PCA + Clusters    - Accuracy: {score_pca_clusters[1]:.4f}")
print("=" * 60)

# Discussion: [Which performed best? Why might that be?]
# I would pick [chosen method] because [reasoning about accuracy, 
# interpretability, computational efficiency, etc.]
# Out:
# ============================================================
# MODEL COMPARISON
# ============================================================
# Original Features - Accuracy: 0.4322
# PCA Components    - Accuracy: 0.4477
# PCA + Clusters    - Accuracy: 0.4322
# ============================================================

# %% [markdown]
# ---
#
# ## Model Performance Analysis
#
# The **PCA model performed best** with 44.77% accuracy, followed by both the original features and PCA+Clusters models at 43.22%.
#
# **Key Observations:**
# 1. PCA slightly outperformed original features despite 50% dimensionality reduction
# 2. Adding cluster membership didn't improve performance beyond PCA alone
# 3. All models show signs of overfitting (100% train accuracy, ~44% test accuracy)
#
# ## Recommendation
#
# **I would choose the PCA model** for the following reasons:
# - Best test accuracy (44.77%)
# - 50% fewer features (120 vs 241) improves computational efficiency
# - Reduced dimensionality helps prevent overfitting in practice
# - Faster training and prediction times
# - More interpretable through variance-based components
#
# **Why cluster features didn't add value:**
# - Clusters may capture variation already represented in PCA components
# - Only 4 clusters provide limited discriminative power
# - The single binary cluster variable adds minimal information compared to 120 continuous PCA components

# %% [markdown]
# ---
# ## Discussion Questions

# %% [markdown]
# ### 1. In your own words, what is the difference between PCA and clustering?

# %% [markdown]
# PCA (Principal Component Analysis) is a dimensionality reduction technique that transforms features into a smaller set of uncorrelated components that capture the most variance in the data. It reduces the number of columns (features) while preserving as much information as possible.
# Clustering is a grouping technique that partitions observations into distinct groups based on similarity. It identifies patterns in the rows (observations) by grouping similar data points together, without using labeled outcomes.

# %% [markdown]
# ### 2. Did you notice any advantages to combining PCA and clustering? If so, what do you think they were? If not, why do you think you didn't see any gains from this combination?

# %% [markdown]
# There wasn't a significant advantage to combining PCA and clustering in this case. The PCA+Clusters model (43.22%) actually performed slightly worse than PCA alone (44.77%).
#
# **Possible reasons:**
# - The clustering captured variation already represented in the PCA components, providing redundant rather than complementary information
# - With only 4 clusters, the single categorical cluster variable didn't add enough discriminative power compared to 120 continuous PCA components
# - The health outcome may be too complex to be captured by simple demographic/health clusters
# - The clusters might reflect the same underlying patterns that the first few principal components already capture
#
# **Alternative approaches that might work better:**
# - Using more clusters (e.g., 10-20) to add more granular group information
# - Trying different clustering algorithms like DBSCAN or hierarchical clustering
# - Creating interaction features between cluster membership and key PCA components

# %% [markdown]
# ### 3. How can unsupervised techniques help with downstream supervised learning tasks when working with "big data?"

# %% [markdown]
# Unsupervised techniques help by:
#
# - **Reducing dimensionality (PCA):** Makes models faster, prevents overfitting, and removes noise
# - **Feature engineering (clustering):** Creates new features that capture group patterns
# - **Data exploration:** Helps understand structure before building predictive models
# - **Computational efficiency:** Reduces the curse of dimensionality in high-dimensional datasets
#
# For my study, PCA reduced ~250 features to ~120 components while maintaining similar accuracy, making the model more efficient and reducing the risk of overfitting while preserving predictive power.

# %% [markdown]
# ---
#
# ## Project Summary
#
# **Dataset:** 2,064 observations, 241 original features
# **PCA Reduction:** 241 features → 120 components (50% reduction)
# **Clusters Identified:** 4
# **Best Model:** PCA Components (44.77% accuracy)
#
# **Key Insight:** PCA successfully reduced dimensionality by 50% while maintaining (and slightly improving) predictive performance, demonstrating the value of unsupervised learning for feature engineering in health prediction tasks. The combination of PCA and clustering did not provide additional benefits, suggesting that the clusters captured information already represented in the principal components.
